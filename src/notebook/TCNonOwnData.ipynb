# %%
# Install necessary packages (add others if your script requires them)
# !pip install joblib -q # -q makes it quieter

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense, Dropout, BatchNormalization, Add
from tensorflow.keras.layers import Conv1D, SpatialDropout1D, GlobalAveragePooling1D, Activation
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, EarlyStopping
from tensorflow.keras.regularizers import l2
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score
from sklearn.utils import class_weight
import seaborn as sns
import joblib
import os
import time

# %%
# --- Configuration ---
from pathlib import Path # Ensure Path is imported

# *** Define the two input files using Colab paths ***
# Assuming you created Colab_HAR_Project/data in your Drive's root
drive_base_path = Path('/content/drive/MyDrive/Colab_HAR_Project/data')
INPUT_CSV_1 = drive_base_path / 'resampled_normalized_phone_data.csv' # Source for B, D, E
INPUT_CSV_2 = drive_base_path / 'combined_collected_data.csv'      # Source for A, C

ACTIVITIES_FROM_FILE1 = ['B', 'D', 'E']
ACTIVITIES_FROM_FILE2 = ['A', 'C']
ALL_ACTIVITIES_TO_KEEP = sorted(ACTIVITIES_FROM_FILE1 + ACTIVITIES_FROM_FILE2)

# *** Define the output directory within Google Drive for persistence ***
output_drive_path = Path('/content/drive/MyDrive/Colab_HAR_Project/results')
OUTPUT_DIR = output_drive_path / 'TCN_Results_Merged_Sources_Colab' # Use a distinct name
FILE_PREFIX = f"tcn_{''.join(ALL_ACTIVITIES_TO_KEEP)}_"

# Create output directory (in Google Drive via the mount)
# os.makedirs(OUTPUT_DIR, exist_ok=True) # Pathlib handles this better
OUTPUT_DIR.mkdir(parents=True, exist_ok=True) # Use pathlib's mkdir

# --- Windowing, Model, Training Parameters (Keep as before or adjust) ---
# ... (rest of your configuration variables like WINDOW_SIZE, BATCH_SIZE etc.) ...

# --- Add GPU Check (Optional but recommended) ---
import tensorflow as tf
print("--- GPU Check ---")
print(f"TensorFlow Version: {tf.__version__}")
gpu_devices = tf.config.list_physical_devices('GPU')
print(f"Num GPUs Available: {len(gpu_devices)}")
if gpu_devices:
    print("GPU(s) found:")
    for gpu in gpu_devices:
        print(f"  {gpu}")
        try: # Attempt memory growth setting
            tf.config.experimental.set_memory_growth(gpu, True)
        except RuntimeError as e:
            print(f"Could not set memory growth for {gpu}: {e}")
    print("Attempted to enable memory growth for GPU(s).")
else:
    print("!!! No GPU found by TensorFlow. Check Runtime settings. !!!")
print("-----------------\n")


# Windowing Parameters
WINDOW_SIZE = 60
STRIDE = 15

# Model Hyperparameters
KERNEL_SIZE = 7
NUM_FILTERS = 64
NUM_TCN_BLOCKS = 5
DILATION_RATES = [2**i for i in range(NUM_TCN_BLOCKS)]
SPATIAL_DROPOUT_RATE = 0.15
FINAL_DROPOUT_RATE = 0.3
L2_REG = 1e-4

# Training Parameters
BATCH_SIZE = 64
EPOCHS = 100
VALIDATION_SPLIT = 0.2
EARLY_STOPPING_PATIENCE = 15
LR_PATIENCE = 5
LR_FACTOR = 0.5

# --- Create output directory ---
os.makedirs(OUTPUT_DIR, exist_ok=True)

print("--- Configuration ---")
print(f"Input CSV 1 (Activities {ACTIVITIES_FROM_FILE1}): {INPUT_CSV_1}")
print(f"Input CSV 2 (Activities {ACTIVITIES_FROM_FILE2}): {INPUT_CSV_2}")
print(f"All Activities Kept: {ALL_ACTIVITIES_TO_KEEP}")
print(f"Output Directory: {OUTPUT_DIR}")
print(f"Output File Prefix: {FILE_PREFIX}")
print(f"Window Size: {WINDOW_SIZE} samples")
print(f"Stride: {STRIDE} samples")
print(f"TCN Kernel Size: {KERNEL_SIZE}")

print("---------------------\n")


# --- Data Preparation Function (Windowing) ---
# No changes needed in this function itself, it operates on the final combined dataframe
def create_subject_activity_windows(df, window_size, stride):
    """
    Creates sliding windows ensuring each window belongs to only one subject/activity pair.
    """
    windows = []
    labels = []
    subject_ids = []

    required_cols = ['x_accel', 'y_accel', 'z_accel', 'x_gyro', 'y_gyro', 'z_gyro']
    if not all(col in df.columns for col in required_cols):
        raise ValueError(f"Input DataFrame missing required sensor columns: {required_cols}")
    if 'subject' not in df.columns or 'activity' not in df.columns:
        raise ValueError("Input DataFrame missing 'subject' or 'activity' columns.")
    if 'timestamp' not in df.columns:
        print("Warning: 'timestamp' column not found. Assuming data is pre-sorted.")

    grouped = df.groupby(['subject', 'activity'])
    print(f"Processing {len(grouped)} subject-activity groups for windowing...")

    for name, group_df in grouped:
        subject, activity = name
        if 'timestamp' in group_df.columns:
             group_df = group_df.sort_values('timestamp')

        data_values = group_df[required_cols].values

        if len(data_values) < window_size:
            continue

        for start_idx in range(0, data_values.shape[0] - window_size + 1, stride):
            window = data_values[start_idx : start_idx + window_size, :]
            windows.append(window)
            labels.append(activity)
            subject_ids.append(subject)

    if not windows:
        raise ValueError("No windows could be created. Check filtered data length and window parameters.")

    X = np.array(windows)
    y = np.array(labels)
    subs = np.array(subject_ids)

    print(f"\nCreated {len(windows)} windows.")
    print(f"Window data shape (X): {X.shape}")
    print(f"Labels shape (y): {y.shape}")

    return X, y, subs


# --- TCN Model Definition ---

def residual_block(x, dilation_rate, nb_filters, kernel_size, padding, dropout_rate=0.0, l2_reg=0.0):
    prev_x = x
    conv1 = Conv1D(filters=nb_filters, kernel_size=kernel_size, dilation_rate=dilation_rate, padding=padding, kernel_regularizer=l2(l2_reg))(x)
    conv1 = BatchNormalization()(conv1); conv1 = Activation('relu')(conv1); conv1 = SpatialDropout1D(dropout_rate)(conv1)
    conv2 = Conv1D(filters=nb_filters, kernel_size=kernel_size, dilation_rate=dilation_rate, padding=padding, kernel_regularizer=l2(l2_reg))(conv1)
    conv2 = BatchNormalization()(conv2); conv2 = Activation('relu')(conv2); conv2 = SpatialDropout1D(dropout_rate)(conv2)
    if prev_x.shape[-1] != conv2.shape[-1]: prev_x = Conv1D(nb_filters, 1, padding='same', kernel_regularizer=l2(l2_reg))(prev_x)
    res_x = Add()([prev_x, conv2]); return res_x

def build_tcn_model(input_shape, num_classes, kernel_size, num_filters, dilation_rates, spatial_dropout, final_dropout, l2_reg=0.0):
    input_layer = Input(shape=input_shape)
    x = input_layer
    for dilation_rate in dilation_rates:
        x = residual_block(x, dilation_rate, num_filters, kernel_size, padding='same', dropout_rate=spatial_dropout, l2_reg=l2_reg)
    x = GlobalAveragePooling1D()(x)
    x = Dropout(final_dropout)(x)
    output_layer = Dense(num_classes, activation='softmax', kernel_regularizer=l2(l2_reg))(x)
    model = Model(inputs=input_layer, outputs=output_layer)
    return model


# --- Plotting and Evaluation Functions ---
# (Modified to use FILE_PREFIX in filenames)
def plot_confusion_matrix(y_true, y_pred_classes, class_names, output_dir, filename_suffix="confusion_matrix.png"):
    cm = confusion_matrix(y_true, y_pred_classes)
    plt.figure(figsize=(max(6, len(class_names)+1), max(5, len(class_names)*0.8+1)))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=class_names, yticklabels=class_names)
    plt.ylabel('Actual'); plt.xlabel('Predicted')
    plt.title(f'Confusion Matrix ({FILE_PREFIX[:-1]})'); plt.tight_layout()
    filepath = os.path.join(output_dir, FILE_PREFIX + filename_suffix); plt.savefig(filepath); plt.close()
    print(f"Confusion matrix saved to {filepath}")

def plot_training_history(history, output_dir, filename_suffix="training_history.png"):
    plt.figure(figsize=(12, 5))
    plt.subplot(1, 2, 1); plt.plot(history.history['accuracy'], label='Train Acc')
    if 'val_accuracy' in history.history: plt.plot(history.history['val_accuracy'], label='Val Acc')
    plt.title('Accuracy'); plt.ylabel('Accuracy'); plt.xlabel('Epoch'); plt.legend(loc='lower right')
    plt.subplot(1, 2, 2); plt.plot(history.history['loss'], label='Train Loss')
    if 'val_loss' in history.history: plt.plot(history.history['val_loss'], label='Val Loss')
    plt.title('Loss'); plt.ylabel('Loss'); plt.xlabel('Epoch'); plt.legend(loc='upper right')
    plt.suptitle(f'Training History ({FILE_PREFIX[:-1]})') # Add overall title
    plt.tight_layout(rect=[0, 0.03, 1, 0.95]) # Adjust layout for suptitle
    filepath = os.path.join(output_dir, FILE_PREFIX + filename_suffix); plt.savefig(filepath); plt.close()
    print(f"Training history plot saved to {filepath}")

def save_classification_report(y_true, y_pred_classes, class_names, output_dir, filename_suffix="classification_report.txt"):
    report = classification_report(y_true, y_pred_classes, target_names=class_names, digits=4, zero_division=0)
    report_path = os.path.join(output_dir, FILE_PREFIX + filename_suffix)
    with open(report_path, 'w') as f:
        f.write(f"Classification Report ({FILE_PREFIX[:-1]}):\n")
        f.write("=======================================\n")
        f.write(report)
    print(f"Classification report saved to {report_path}")
    return report

def save_predictions(y_true, y_pred_proba, y_pred_classes, subjects_test, label_encoder, output_dir, filename_suffix="test_predictions.csv"):
    df_results = pd.DataFrame({'subject': subjects_test,
                               'true_label_encoded': y_true,
                               'true_label_name': label_encoder.inverse_transform(y_true),
                               'predicted_label_encoded': y_pred_classes,
                               'predicted_label_name': label_encoder.inverse_transform(y_pred_classes)})
    for i, class_name in enumerate(label_encoder.classes_):
        df_results[f'prob_{class_name}'] = y_pred_proba[:, i]
    pred_path = os.path.join(output_dir, FILE_PREFIX + filename_suffix)
    df_results.to_csv(pred_path, index=False)
    print(f"Test set predictions saved to {pred_path}")


# --- Main Execution ---
if __name__ == "__main__":
    main_start_time = time.time()

    # 1. Load and Filter Data from Both Sources
    print(f"\n[1/7] Loading and filtering data...")
    all_data_frames = []

    # Load and filter from file 1
    try:
        print(f"  Loading {INPUT_CSV_1} for activities {ACTIVITIES_FROM_FILE1}...")
        df1 = pd.read_csv(INPUT_CSV_1)
        df1_filtered = df1[df1['activity'].isin(ACTIVITIES_FROM_FILE1)].copy() # Filter
        if not df1_filtered.empty:
             print(f"    Kept {len(df1_filtered)} rows from {INPUT_CSV_1}.")
             all_data_frames.append(df1_filtered)
        else:
             print(f"    Warning: No data found for activities {ACTIVITIES_FROM_FILE1} in {INPUT_CSV_1}.")
    except FileNotFoundError:
        print(f"  ERROR: Input file {INPUT_CSV_1} not found. Skipping.")
    except Exception as e:
        print(f"  ERROR: Could not load or filter {INPUT_CSV_1}: {e}. Skipping.")

    # Load and filter from file 2
    try:
        print(f"  Loading {INPUT_CSV_2} for activities {ACTIVITIES_FROM_FILE2}...")
        if not INPUT_CSV_2.is_file():
             raise FileNotFoundError(f"{INPUT_CSV_2} not found.")
        df2 = pd.read_csv(INPUT_CSV_2)
        df2_filtered = df2[df2['activity'].isin(ACTIVITIES_FROM_FILE2)].copy() # Filter
        if not df2_filtered.empty:
             print(f"    Kept {len(df2_filtered)} rows from {INPUT_CSV_2}.")
             all_data_frames.append(df2_filtered)
        else:
             print(f"    Warning: No data found for activities {ACTIVITIES_FROM_FILE2} in {INPUT_CSV_2}.")
    except FileNotFoundError:
        print(f"  ERROR: Input file {INPUT_CSV_2} not found. Skipping.")
    except Exception as e:
        print(f"  ERROR: Could not load or filter {INPUT_CSV_2}: {e}. Skipping.")

    # 2. Combine Data
    print("\n[2/7] Combining filtered data...")
    if not all_data_frames:
        print("FATAL ERROR: No data loaded from any source. Check file paths and activity lists.")
        exit()

    combined_df = pd.concat(all_data_frames, ignore_index=True)
    print(f"Combined dataset created with {len(combined_df)} rows.")

    # Verify final activities
    final_activities = combined_df['activity'].unique()
    print(f"Activities present in combined data: {sorted(final_activities)}")
    if set(final_activities) != set(ALL_ACTIVITIES_TO_KEEP):
        print("Warning: The activities in the final combined data do not exactly match the expected set.")
        print(f"  Expected: {ALL_ACTIVITIES_TO_KEEP}")
        print(f"  Found: {sorted(final_activities)}")
        # Decide if this is fatal or acceptable
        # For now, we continue but this might indicate an issue in filtering or input data

    # Check for necessary columns before windowing
    required_cols_for_windowing = ['subject', 'activity', 'timestamp', 'x_accel', 'y_accel', 'z_accel', 'x_gyro', 'y_gyro', 'z_gyro']
    missing_cols = [col for col in required_cols_for_windowing if col not in combined_df.columns and col != 'timestamp'] # Timestamp check is in windowing func
    if missing_cols:
        print(f"FATAL ERROR: Combined DataFrame is missing essential columns for windowing: {missing_cols}")
        exit()


    # 3. Create Windows
    print(f"\n[3/7] Creating sliding windows (size={WINDOW_SIZE}, stride={STRIDE})...")
    try:
        X, y_raw_labels, subjects = create_subject_activity_windows(combined_df, WINDOW_SIZE, STRIDE)
        # X shape: (num_windows, window_size, num_features)
        # y_raw_labels shape: (num_windows,)
        # subjects shape: (num_windows,)
    except Exception as e:
        print(f"FATAL ERROR: Failed to create windows: {e}")
        exit()

    # 4. Encode Labels
    print("\n[4/7] Encoding activity labels...")
    label_encoder = LabelEncoder()
    y = label_encoder.fit_transform(y_raw_labels)
    num_classes = len(label_encoder.classes_)
    # Ensure the encoder classes match the intended activities
    print(f"Encoded {num_classes} unique classes: {label_encoder.classes_}")
    if set(label_encoder.classes_) != set(ALL_ACTIVITIES_TO_KEEP):
         print("Warning: Label encoder classes do not match the full set of intended activities. This might happen if some activities had no data after windowing.")
         print(f"  Intended: {ALL_ACTIVITIES_TO_KEEP}")
         print(f"  Encoded: {list(label_encoder.classes_)}")
    # Save label encoder
    le_path = os.path.join(OUTPUT_DIR, FILE_PREFIX + 'label_encoder.joblib')
    joblib.dump(label_encoder, le_path)
    print(f"Label encoder saved to {le_path}")

    # 5. Split Data (Train/Test)
    print("\n[5/7] Splitting data into training and testing sets...")
    X_train, X_test, y_train, y_test, subjects_train, subjects_test = train_test_split(
        X, y, subjects,
        test_size=0.25,
        random_state=42,
        stratify=y
    )
    print(f"Training set shape: X={X_train.shape}, y={y_train.shape}")
    print(f"Testing set shape: X={X_test.shape}, y={y_test.shape}")


    # 6. Scale Features
    print("\n[6/7] Scaling features using StandardScaler...")
    if len(X_train.shape) != 3:
         print(f"FATAL ERROR: X_train does not have 3 dimensions. Shape: {X_train.shape}")
         exit()
    num_samples_train, timesteps, num_features = X_train.shape
    num_samples_test = X_test.shape[0]

    X_train_reshaped = X_train.reshape(-1, num_features)
    X_test_reshaped = X_test.reshape(-1, num_features)

    scaler = StandardScaler()
    X_train_scaled_reshaped = scaler.fit_transform(X_train_reshaped)
    X_test_scaled_reshaped = scaler.transform(X_test_reshaped)

    X_train_scaled = X_train_scaled_reshaped.reshape(num_samples_train, timesteps, num_features)
    X_test_scaled = X_test_scaled_reshaped.reshape(num_samples_test, timesteps, num_features)
    print("Scaling complete.")
    scaler_path = os.path.join(OUTPUT_DIR, FILE_PREFIX + 'scaler.joblib')
    joblib.dump(scaler, scaler_path)
    print(f"Scaler saved to {scaler_path}")

    # 7. Build and Train Model
    print("\n[7/7] Building and training TCN model...")
    input_shape = (WINDOW_SIZE, num_features)
    model = build_tcn_model(input_shape, num_classes, KERNEL_SIZE, NUM_FILTERS,
                             DILATION_RATES, SPATIAL_DROPOUT_RATE, FINAL_DROPOUT_RATE, L2_REG)

    model.compile(optimizer=tf.keras.optimizers.Adam(),
                  loss='sparse_categorical_crossentropy',
                  metrics=['accuracy'])
    model.summary(print_fn=lambda x: print(x))

    # Calculate Class Weights
    print("Calculating class weights...")
    unique_classes_train, counts_train = np.unique(y_train, return_counts=True)
    print(f"Training data class distribution: {dict(zip(label_encoder.inverse_transform(unique_classes_train), counts_train))}")

    if not np.all(unique_classes_train >= 0) or not np.all(unique_classes_train < num_classes):
        print(f"Warning: Class indices in y_train seem invalid. Unique values: {unique_classes_train}.")
        class_weights_dict = None
    else:
        class_weights_array = class_weight.compute_class_weight(
            class_weight='balanced',
            classes=unique_classes_train,
            y=y_train
        )
        class_weights_dict = dict(zip(unique_classes_train, class_weights_array))
        print(f"Class weights computed: {class_weights_dict}")


    # Define Callbacks
    checkpoint_path = os.path.join(OUTPUT_DIR, FILE_PREFIX + 'har_model.keras')
    model_checkpoint = ModelCheckpoint(filepath=checkpoint_path, monitor='val_accuracy', save_best_only=True, mode='max', verbose=1)
    reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=LR_FACTOR, patience=LR_PATIENCE, min_lr=1e-6, verbose=1)
    early_stopping = EarlyStopping(monitor='val_loss', patience=EARLY_STOPPING_PATIENCE, restore_best_weights=True, verbose=1)
    callbacks_list = [model_checkpoint, reduce_lr, early_stopping]

    # Train the Model
    history = model.fit(
        X_train_scaled, y_train,
        epochs=EPOCHS, batch_size=BATCH_SIZE,
        validation_split=VALIDATION_SPLIT,
        callbacks=callbacks_list,
        class_weight=class_weights_dict,
        verbose=1
    )

    print("Training finished.")
    plot_training_history(history, OUTPUT_DIR)

    # Load Best Model
    print("\nLoading best model weights saved during training...")
    try:
        best_model = tf.keras.models.load_model(checkpoint_path)
        print("Best model loaded successfully.")
    except Exception as e:
        print(f"Warning: Could not load best model from checkpoint ({e}). Using model state from end of training.")
        best_model = model


    # 8. Evaluate Model and Save Results
    print("\n[8/8] Evaluating model and saving results...") # Step number updated
    test_loss, test_acc = best_model.evaluate(X_test_scaled, y_test, verbose=0)
    print(f"\nTest Loss: {test_loss:.4f}")
    print(f"Test Accuracy: {test_acc:.4f}")

    y_pred_proba = best_model.predict(X_test_scaled)
    y_pred_classes = np.argmax(y_pred_proba, axis=1)

    # Get actual class names for reporting
    report_class_names = label_encoder.classes_

    report_str = save_classification_report(y_test, y_pred_classes, report_class_names, OUTPUT_DIR)
    print("\n" + report_str)
    plot_confusion_matrix(y_test, y_pred_classes, report_class_names, OUTPUT_DIR)
    save_predictions(y_test, y_pred_proba, y_pred_classes, subjects_test, label_encoder, OUTPUT_DIR)


    main_end_time = time.time()
    print(f"\n--- Script finished in {main_end_time - main_start_time:.2f} seconds ---")
# Out:
# --- GPU Check ---
# TensorFlow Version: 2.18.0
# Num GPUs Available: 1
# GPU(s) found:
#   PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')
# Attempted to enable memory growth for GPU(s).
# -----------------
#
# --- Configuration ---
# Input CSV 1 (Activities ['B', 'D', 'E']): /content/drive/MyDrive/Colab_HAR_Project/data/resampled_normalized_phone_data.csv
# Input CSV 2 (Activities ['A', 'C']): /content/drive/MyDrive/Colab_HAR_Project/data/combined_collected_data.csv
# All Activities Kept: ['A', 'B', 'C', 'D', 'E']
# Output Directory: /content/drive/MyDrive/Colab_HAR_Project/results/TCN_Results_Merged_Sources_Colab
# Output File Prefix: tcn_ABCDE_
# Window Size: 60 samples
# Stride: 15 samples
# TCN Kernel Size: 7
# ---------------------
#
#
# [1/7] Loading and filtering data...
#   Loading /content/drive/MyDrive/Colab_HAR_Project/data/resampled_normalized_phone_data.csv for activities ['B', 'D', 'E']...
#     Kept 542962 rows from /content/drive/MyDrive/Colab_HAR_Project/data/resampled_normalized_phone_data.csv.
#   Loading /content/drive/MyDrive/Colab_HAR_Project/data/combined_collected_data.csv for activities ['A', 'C']...
#     Kept 307887 rows from /content/drive/MyDrive/Colab_HAR_Project/data/combined_collected_data.csv.
#
# [2/7] Combining filtered data...
# Combined dataset created with 850849 rows.
# Activities present in combined data: ['A', 'B', 'C', 'D', 'E']
#
# [3/7] Creating sliding windows (size=60, stride=15)...
# Processing 178 subject-activity groups for windowing...
#
# Created 56083 windows.
# Window data shape (X): (56083, 60, 6)
# Labels shape (y): (56083,)
#
# [4/7] Encoding activity labels...
# Encoded 5 unique classes: ['A' 'B' 'C' 'D' 'E']
# Label encoder saved to /content/drive/MyDrive/Colab_HAR_Project/results/TCN_Results_Merged_Sources_Colab/tcn_ABCDE_label_encoder.joblib
#
# [5/7] Splitting data into training and testing sets...
# Training set shape: X=(42062, 60, 6), y=(42062,)
# Testing set shape: X=(14021, 60, 6), y=(14021,)
#
# [6/7] Scaling features using StandardScaler...
# Scaling complete.
# Scaler saved to /content/drive/MyDrive/Colab_HAR_Project/results/TCN_Results_Merged_Sources_Colab/tcn_ABCDE_scaler.joblib
#
# [7/7] Building and training TCN model...
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_1             │ (None, 60, 6)          │              0 │ -                      │
# │ (InputLayer)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv1d_11 (Conv1D)        │ (None, 60, 64)         │          2,752 │ input_layer_1[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_10    │ (None, 60, 64)         │            256 │ conv1d_11[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_10             │ (None, 60, 64)         │              0 │ batch_normalization_1… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ spatial_dropout1d_10      │ (None, 60, 64)         │              0 │ activation_10[0][0]    │
# │ (SpatialDropout1D)        │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv1d_12 (Conv1D)        │ (None, 60, 64)         │         28,736 │ spatial_dropout1d_10[… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_11    │ (None, 60, 64)         │            256 │ conv1d_12[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_11             │ (None, 60, 64)         │              0 │ batch_normalization_1… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv1d_13 (Conv1D)        │ (None, 60, 64)         │            448 │ input_layer_1[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ spatial_dropout1d_11      │ (None, 60, 64)         │              0 │ activation_11[0][0]    │
# │ (SpatialDropout1D)        │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_5 (Add)               │ (None, 60, 64)         │              0 │ conv1d_13[0][0],       │
# │                           │                        │                │ spatial_dropout1d_11[… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv1d_14 (Conv1D)        │ (None, 60, 64)         │         28,736 │ add_5[0][0]            │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_12    │ (None, 60, 64)         │            256 │ conv1d_14[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_12             │ (None, 60, 64)         │              0 │ batch_normalization_1… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ spatial_dropout1d_12      │ (None, 60, 64)         │              0 │ activation_12[0][0]    │
# │ (SpatialDropout1D)        │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv1d_15 (Conv1D)        │ (None, 60, 64)         │         28,736 │ spatial_dropout1d_12[… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_13    │ (None, 60, 64)         │            256 │ conv1d_15[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_13             │ (None, 60, 64)         │              0 │ batch_normalization_1… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ spatial_dropout1d_13      │ (None, 60, 64)         │              0 │ activation_13[0][0]    │
# │ (SpatialDropout1D)        │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_6 (Add)               │ (None, 60, 64)         │              0 │ add_5[0][0],           │
# │                           │                        │                │ spatial_dropout1d_13[… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv1d_16 (Conv1D)        │ (None, 60, 64)         │         28,736 │ add_6[0][0]            │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_14    │ (None, 60, 64)         │            256 │ conv1d_16[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_14             │ (None, 60, 64)         │              0 │ batch_normalization_1… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ spatial_dropout1d_14      │ (None, 60, 64)         │              0 │ activation_14[0][0]    │
# │ (SpatialDropout1D)        │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv1d_17 (Conv1D)        │ (None, 60, 64)         │         28,736 │ spatial_dropout1d_14[… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_15    │ (None, 60, 64)         │            256 │ conv1d_17[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_15             │ (None, 60, 64)         │              0 │ batch_normalization_1… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ spatial_dropout1d_15      │ (None, 60, 64)         │              0 │ activation_15[0][0]    │
# │ (SpatialDropout1D)        │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_7 (Add)               │ (None, 60, 64)         │              0 │ add_6[0][0],           │
# │                           │                        │                │ spatial_dropout1d_15[… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv1d_18 (Conv1D)        │ (None, 60, 64)         │         28,736 │ add_7[0][0]            │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_16    │ (None, 60, 64)         │            256 │ conv1d_18[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_16             │ (None, 60, 64)         │              0 │ batch_normalization_1… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ spatial_dropout1d_16      │ (None, 60, 64)         │              0 │ activation_16[0][0]    │
# │ (SpatialDropout1D)        │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv1d_19 (Conv1D)        │ (None, 60, 64)         │         28,736 │ spatial_dropout1d_16[… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_17    │ (None, 60, 64)         │            256 │ conv1d_19[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_17             │ (None, 60, 64)         │              0 │ batch_normalization_1… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ spatial_dropout1d_17      │ (None, 60, 64)         │              0 │ activation_17[0][0]    │
# │ (SpatialDropout1D)        │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_8 (Add)               │ (None, 60, 64)         │              0 │ add_7[0][0],           │
# │                           │                        │                │ spatial_dropout1d_17[… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv1d_20 (Conv1D)        │ (None, 60, 64)         │         28,736 │ add_8[0][0]            │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_18    │ (None, 60, 64)         │            256 │ conv1d_20[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_18             │ (None, 60, 64)         │              0 │ batch_normalization_1… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ spatial_dropout1d_18      │ (None, 60, 64)         │              0 │ activation_18[0][0]    │
# │ (SpatialDropout1D)        │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv1d_21 (Conv1D)        │ (None, 60, 64)         │         28,736 │ spatial_dropout1d_18[… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_19    │ (None, 60, 64)         │            256 │ conv1d_21[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_19             │ (None, 60, 64)         │              0 │ batch_normalization_1… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ spatial_dropout1d_19      │ (None, 60, 64)         │              0 │ activation_19[0][0]    │
# │ (SpatialDropout1D)        │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_9 (Add)               │ (None, 60, 64)         │              0 │ add_8[0][0],           │
# │                           │                        │                │ spatial_dropout1d_19[… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ global_average_pooling1d… │ (None, 64)             │              0 │ add_9[0][0]            │
# │ (GlobalAveragePooling1D)  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_1 (Dropout)       │ (None, 64)             │              0 │ global_average_poolin… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_1 (Dense)           │ (None, 5)              │            325 │ dropout_1[0][0]        │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 264,709 (1.01 MB)
#  Trainable params: 263,429 (1.00 MB)
#  Non-trainable params: 1,280 (5.00 KB)
#
# Calculating class weights...
# Training data class distribution: {np.str_('A'): np.int64(12295), np.str_('B'): np.int64(8676), np.str_('C'): np.int64(3029), np.str_('D'): np.int64(9032), np.str_('E'): np.int64(9030)}
# Class weights computed: {np.int64(0): np.float64(0.6842130947539651), np.int64(1): np.float64(0.9696173351775011), np.int64(2): np.float64(2.7772862330802246), np.int64(3): np.float64(0.9313994685562444), np.int64(4): np.float64(0.9316057585825027)}
# Epoch 1/100
# 526/526 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.7627 - loss: 0.8336
# Epoch 1: val_accuracy improved from -inf to 0.93427, saving model to /content/drive/MyDrive/Colab_HAR_Project/results/TCN_Results_Merged_Sources_Colab/tcn_ABCDE_har_model.keras
# 526/526 ━━━━━━━━━━━━━━━━━━━━ 40s 41ms/step - accuracy: 0.7629 - loss: 0.8329 - val_accuracy: 0.9343 - val_loss: 0.2030 - learning_rate: 0.0010
# Epoch 2/100
# 521/526 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9248 - loss: 0.2763
# Epoch 2: val_accuracy improved from 0.93427 to 0.95685, saving model to /content/drive/MyDrive/Colab_HAR_Project/results/TCN_Results_Merged_Sources_Colab/tcn_ABCDE_har_model.keras
# 526/526 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step - accuracy: 0.9249 - loss: 0.2760 - val_accuracy: 0.9569 - val_loss: 0.1602 - learning_rate: 0.0010
# Epoch 3/100
# 521/526 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9401 - loss: 0.2129
# Epoch 3: val_accuracy did not improve from 0.95685
# 526/526 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.9401 - loss: 0.2130 - val_accuracy: 0.9506 - val_loss: 0.1638 - learning_rate: 0.0010
# Epoch 4/100
# 525/526 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9423 - loss: 0.1988
# Epoch 4: val_accuracy improved from 0.95685 to 0.96208, saving model to /content/drive/MyDrive/Colab_HAR_Project/results/TCN_Results_Merged_Sources_Colab/tcn_ABCDE_har_model.keras
# 526/526 ━━━━━━━━━━━━━━━━━━━━ 6s 11ms/step - accuracy: 0.9423 - loss: 0.1988 - val_accuracy: 0.9621 - val_loss: 0.1408 - learning_rate: 0.0010
# Epoch 5/100
# 525/526 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9494 - loss: 0.1813
# Epoch 5: val_accuracy did not improve from 0.96208
# 526/526 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.9494 - loss: 0.1813 - val_accuracy: 0.9579 - val_loss: 0.1413 - learning_rate: 0.0010
# Epoch 6/100
# 525/526 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9497 - loss: 0.1821
# Epoch 6: val_accuracy did not improve from 0.96208
# 526/526 ━━━━━━━━━━━━━━━━━━━━ 11s 10ms/step - accuracy: 0.9497 - loss: 0.1821 - val_accuracy: 0.9578 - val_loss: 0.1319 - learning_rate: 0.0010
# Epoch 7/100
# 523/526 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9521 - loss: 0.1640
# Epoch 7: val_accuracy improved from 0.96208 to 0.96898, saving model to /content/drive/MyDrive/Colab_HAR_Project/results/TCN_Results_Merged_Sources_Colab/tcn_ABCDE_har_model.keras
# 526/526 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.9521 - loss: 0.1640 - val_accuracy: 0.9690 - val_loss: 0.1218 - learning_rate: 0.0010
# Epoch 8/100
# 523/526 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9533 - loss: 0.1680
# Epoch 8: val_accuracy did not improve from 0.96898
# 526/526 ━━━━━━━━━━━━━━━━━━━━ 6s 11ms/step - accuracy: 0.9533 - loss: 0.1680 - val_accuracy: 0.9671 - val_loss: 0.1231 - learning_rate: 0.0010
# Epoch 9/100
# 525/526 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9558 - loss: 0.1553
# Epoch 9: val_accuracy did not improve from 0.96898
# 526/526 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.9558 - loss: 0.1553 - val_accuracy: 0.9683 - val_loss: 0.1146 - learning_rate: 0.0010
# Epoch 10/100
# 523/526 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9570 - loss: 0.1483
# Epoch 10: val_accuracy improved from 0.96898 to 0.97361, saving model to /content/drive/MyDrive/Colab_HAR_Project/results/TCN_Results_Merged_Sources_Colab/tcn_ABCDE_har_model.keras
# 526/526 ━━━━━━━━━━━━━━━━━━━━ 6s 11ms/step - accuracy: 0.9570 - loss: 0.1484 - val_accuracy: 0.9736 - val_loss: 0.1166 - learning_rate: 0.0010
# Epoch 11/100
# 521/526 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9549 - loss: 0.1508
# Epoch 11: val_accuracy did not improve from 0.97361
# 526/526 ━━━━━━━━━━━━━━━━━━━━ 10s 10ms/step - accuracy: 0.9549 - loss: 0.1508 - val_accuracy: 0.9685 - val_loss: 0.1227 - learning_rate: 0.0010
# Epoch 12/100
# 521/526 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9562 - loss: 0.1522
# Epoch 12: val_accuracy improved from 0.97361 to 0.97658, saving model to /content/drive/MyDrive/Colab_HAR_Project/results/TCN_Results_Merged_Sources_Colab/tcn_ABCDE_har_model.keras
# 526/526 ━━━━━━━━━━━━━━━━━━━━ 6s 11ms/step - accuracy: 0.9562 - loss: 0.1521 - val_accuracy: 0.9766 - val_loss: 0.1099 - learning_rate: 0.0010
# Epoch 13/100
# 522/526 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9610 - loss: 0.1417
# Epoch 13: val_accuracy did not improve from 0.97658
# 526/526 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.9610 - loss: 0.1417 - val_accuracy: 0.9761 - val_loss: 0.1070 - learning_rate: 0.0010
# Epoch 14/100
# 523/526 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9613 - loss: 0.1444
# Epoch 14: val_accuracy improved from 0.97658 to 0.97932, saving model to /content/drive/MyDrive/Colab_HAR_Project/results/TCN_Results_Merged_Sources_Colab/tcn_ABCDE_har_model.keras
# 526/526 ━━━━━━━━━━━━━━━━━━━━ 10s 10ms/step - accuracy: 0.9613 - loss: 0.1444 - val_accuracy: 0.9793 - val_loss: 0.1013 - learning_rate: 0.0010
# Epoch 15/100
# 521/526 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9641 - loss: 0.1357
# Epoch 15: val_accuracy improved from 0.97932 to 0.98039, saving model to /content/drive/MyDrive/Colab_HAR_Project/results/TCN_Results_Merged_Sources_Colab/tcn_ABCDE_har_model.keras
# 526/526 ━━━━━━━━━━━━━━━━━━━━ 11s 11ms/step - accuracy: 0.9641 - loss: 0.1357 - val_accuracy: 0.9804 - val_loss: 0.1066 - learning_rate: 0.0010
# Epoch 16/100
# 525/526 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9630 - loss: 0.1446
# Epoch 16: val_accuracy did not improve from 0.98039
# 526/526 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.9630 - loss: 0.1446 - val_accuracy: 0.9773 - val_loss: 0.0954 - learning_rate: 0.0010
# Epoch 17/100
# 524/526 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9666 - loss: 0.1331
# Epoch 17: val_accuracy did not improve from 0.98039
# 526/526 ━━━━━━━━━━━━━━━━━━━━ 6s 11ms/step - accuracy: 0.9665 - loss: 0.1331 - val_accuracy: 0.9766 - val_loss: 0.1020 - learning_rate: 0.0010
# Epoch 18/100
# 523/526 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9630 - loss: 0.1436
# Epoch 18: val_accuracy improved from 0.98039 to 0.98181, saving model to /content/drive/MyDrive/Colab_HAR_Project/results/TCN_Results_Merged_Sources_Colab/tcn_ABCDE_har_model.keras
# 526/526 ━━━━━━━━━━━━━━━━━━━━ 10s 10ms/step - accuracy: 0.9630 - loss: 0.1435 - val_accuracy: 0.9818 - val_loss: 0.0941 - learning_rate: 0.0010
# Epoch 19/100
# 523/526 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9661 - loss: 0.1341
# Epoch 19: val_accuracy did not improve from 0.98181
# 526/526 ━━━━━━━━━━━━━━━━━━━━ 10s 10ms/step - accuracy: 0.9661 - loss: 0.1341 - val_accuracy: 0.9817 - val_loss: 0.1035 - learning_rate: 0.0010
# Epoch 20/100
# 521/526 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9671 - loss: 0.1337
# Epoch 20: val_accuracy did not improve from 0.98181
# 526/526 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.9671 - loss: 0.1337 - val_accuracy: 0.9812 - val_loss: 0.0903 - learning_rate: 0.0010
# Epoch 21/100
# 522/526 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9674 - loss: 0.1315
# Epoch 21: val_accuracy improved from 0.98181 to 0.98574, saving model to /content/drive/MyDrive/Colab_HAR_Project/results/TCN_Results_Merged_Sources_Colab/tcn_ABCDE_har_model.keras
# 526/526 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.9674 - loss: 0.1315 - val_accuracy: 0.9857 - val_loss: 0.0928 - learning_rate: 0.0010
# Epoch 22/100
# 524/526 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9676 - loss: 0.1313
# Epoch 22: val_accuracy did not improve from 0.98574
# 526/526 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.9676 - loss: 0.1313 - val_accuracy: 0.9857 - val_loss: 0.0900 - learning_rate: 0.0010
# Epoch 23/100
# 526/526 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9685 - loss: 0.1275
# Epoch 23: val_accuracy did not improve from 0.98574
# 526/526 ━━━━━━━━━━━━━━━━━━━━ 6s 10ms/step - accuracy: 0.9685 - loss: 0.1275 - val_accuracy: 0.9850 - val_loss: 0.0897 - learning_rate: 0.0010
# Epoch 24/100
# 526/526 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9702 - loss: 0.1235
# Epoch 24: val_accuracy did not improve from 0.98574
# 526/526 ━━━━━━━━━━━━━━━━━━━━ 10s 11ms/step - accuracy: 0.9702 - loss: 0.1235 - val_accuracy: 0.9816 - val_loss: 0.0950 - learning_rate: 0.0010
# Epoch 25/100
# 520/526 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9659 - loss: 0.1307
# Epoch 25: val_accuracy did not improve from 0.98574
# 526/526 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.9660 - loss: 0.1307 - val_accuracy: 0.9815 - val_loss: 0.0919 - learning_rate: 0.0010
# Epoch 26/100
# 521/526 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9664 - loss: 0.1289
# Epoch 26: val_accuracy did not improve from 0.98574
# 526/526 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.9664 - loss: 0.1288 - val_accuracy: 0.9844 - val_loss: 0.0886 - learning_rate: 0.0010
# Epoch 27/100
# 521/526 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9708 - loss: 0.1251
# Epoch 27: val_accuracy improved from 0.98574 to 0.98586, saving model to /content/drive/MyDrive/Colab_HAR_Project/results/TCN_Results_Merged_Sources_Colab/tcn_ABCDE_har_model.keras
# 526/526 ━━━━━━━━━━━━━━━━━━━━ 6s 11ms/step - accuracy: 0.9708 - loss: 0.1251 - val_accuracy: 0.9859 - val_loss: 0.0898 - learning_rate: 0.0010
# Epoch 28/100
# 523/526 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9709 - loss: 0.1232
# Epoch 28: val_accuracy did not improve from 0.98586
# 526/526 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.9709 - loss: 0.1232 - val_accuracy: 0.9823 - val_loss: 0.0968 - learning_rate: 0.0010
# Epoch 29/100
# 524/526 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9701 - loss: 0.1221
# Epoch 29: val_accuracy improved from 0.98586 to 0.98776, saving model to /content/drive/MyDrive/Colab_HAR_Project/results/TCN_Results_Merged_Sources_Colab/tcn_ABCDE_har_model.keras
# 526/526 ━━━━━━━━━━━━━━━━━━━━ 6s 11ms/step - accuracy: 0.9701 - loss: 0.1221 - val_accuracy: 0.9878 - val_loss: 0.0833 - learning_rate: 0.0010
# Epoch 30/100
# 522/526 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9689 - loss: 0.1276
# Epoch 30: val_accuracy did not improve from 0.98776
# 526/526 ━━━━━━━━━━━━━━━━━━━━ 9s 9ms/step - accuracy: 0.9689 - loss: 0.1276 - val_accuracy: 0.9872 - val_loss: 0.0832 - learning_rate: 0.0010
# Epoch 31/100
# 524/526 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9695 - loss: 0.1233
# Epoch 31: val_accuracy improved from 0.98776 to 0.98799, saving model to /content/drive/MyDrive/Colab_HAR_Project/results/TCN_Results_Merged_Sources_Colab/tcn_ABCDE_har_model.keras
# 526/526 ━━━━━━━━━━━━━━━━━━━━ 6s 11ms/step - accuracy: 0.9695 - loss: 0.1233 - val_accuracy: 0.9880 - val_loss: 0.0841 - learning_rate: 0.0010
# Epoch 32/100
# 523/526 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9723 - loss: 0.1223
# Epoch 32: val_accuracy did not improve from 0.98799
# 526/526 ━━━━━━━━━━━━━━━━━━━━ 10s 10ms/step - accuracy: 0.9723 - loss: 0.1223 - val_accuracy: 0.9851 - val_loss: 0.0850 - learning_rate: 0.0010
# Epoch 33/100
# 526/526 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9733 - loss: 0.1119
# Epoch 33: val_accuracy improved from 0.98799 to 0.99037, saving model to /content/drive/MyDrive/Colab_HAR_Project/results/TCN_Results_Merged_Sources_Colab/tcn_ABCDE_har_model.keras
# 526/526 ━━━━━━━━━━━━━━━━━━━━ 10s 10ms/step - accuracy: 0.9733 - loss: 0.1119 - val_accuracy: 0.9904 - val_loss: 0.0786 - learning_rate: 0.0010
# Epoch 34/100
# 522/526 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9732 - loss: 0.1150
# Epoch 34: val_accuracy did not improve from 0.99037
# 526/526 ━━━━━━━━━━━━━━━━━━━━ 6s 11ms/step - accuracy: 0.9732 - loss: 0.1150 - val_accuracy: 0.9882 - val_loss: 0.0846 - learning_rate: 0.0010
# Epoch 35/100
# 526/526 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9715 - loss: 0.1175
# Epoch 35: val_accuracy did not improve from 0.99037
# 526/526 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.9715 - loss: 0.1175 - val_accuracy: 0.9779 - val_loss: 0.1060 - learning_rate: 0.0010
# Epoch 36/100
# 526/526 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9722 - loss: 0.1188
# Epoch 36: val_accuracy did not improve from 0.99037
# 526/526 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.9722 - loss: 0.1188 - val_accuracy: 0.9886 - val_loss: 0.0809 - learning_rate: 0.0010
# Epoch 37/100
# 521/526 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9762 - loss: 0.1103
# Epoch 37: val_accuracy did not improve from 0.99037
# 526/526 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.9762 - loss: 0.1104 - val_accuracy: 0.9872 - val_loss: 0.0848 - learning_rate: 0.0010
# Epoch 38/100
# 521/526 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9726 - loss: 0.1194
# Epoch 38: val_accuracy did not improve from 0.99037
#
# Epoch 38: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 526/526 ━━━━━━━━━━━━━━━━━━━━ 11s 11ms/step - accuracy: 0.9726 - loss: 0.1194 - val_accuracy: 0.9862 - val_loss: 0.0794 - learning_rate: 0.0010
# Epoch 39/100
# 526/526 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9789 - loss: 0.1011
# Epoch 39: val_accuracy did not improve from 0.99037
# 526/526 ━━━━━━━━━━━━━━━━━━━━ 10s 10ms/step - accuracy: 0.9789 - loss: 0.1011 - val_accuracy: 0.9874 - val_loss: 0.0725 - learning_rate: 5.0000e-04
# Epoch 40/100
# 522/526 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9788 - loss: 0.0997
# Epoch 40: val_accuracy did not improve from 0.99037
# 526/526 ━━━━━━━━━━━━━━━━━━━━ 10s 9ms/step - accuracy: 0.9788 - loss: 0.0997 - val_accuracy: 0.9895 - val_loss: 0.0685 - learning_rate: 5.0000e-04
# Epoch 41/100
# 521/526 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9799 - loss: 0.0929
# Epoch 41: val_accuracy improved from 0.99037 to 0.99097, saving model to /content/drive/MyDrive/Colab_HAR_Project/results/TCN_Results_Merged_Sources_Colab/tcn_ABCDE_har_model.keras
# 526/526 ━━━━━━━━━━━━━━━━━━━━ 6s 11ms/step - accuracy: 0.9798 - loss: 0.0929 - val_accuracy: 0.9910 - val_loss: 0.0670 - learning_rate: 5.0000e-04
# Epoch 42/100
# 520/526 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9789 - loss: 0.0940
# Epoch 42: val_accuracy did not improve from 0.99097
# 526/526 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.9789 - loss: 0.0940 - val_accuracy: 0.9905 - val_loss: 0.0649 - learning_rate: 5.0000e-04
# Epoch 43/100
# 524/526 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9790 - loss: 0.0914
# Epoch 43: val_accuracy did not improve from 0.99097
# 526/526 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.9790 - loss: 0.0914 - val_accuracy: 0.9893 - val_loss: 0.0655 - learning_rate: 5.0000e-04
# Epoch 44/100
# 521/526 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9814 - loss: 0.0876
# Epoch 44: val_accuracy did not improve from 0.99097
# 526/526 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.9814 - loss: 0.0877 - val_accuracy: 0.9899 - val_loss: 0.0659 - learning_rate: 5.0000e-04
# Epoch 45/100
# 521/526 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9775 - loss: 0.0928
# Epoch 45: val_accuracy did not improve from 0.99097
# 526/526 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.9775 - loss: 0.0928 - val_accuracy: 0.9894 - val_loss: 0.0645 - learning_rate: 5.0000e-04
# Epoch 46/100
# 524/526 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9820 - loss: 0.0870
# Epoch 46: val_accuracy did not improve from 0.99097
# 526/526 ━━━━━━━━━━━━━━━━━━━━ 6s 10ms/step - accuracy: 0.9820 - loss: 0.0870 - val_accuracy: 0.9892 - val_loss: 0.0638 - learning_rate: 5.0000e-04
# Epoch 47/100
# 521/526 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9817 - loss: 0.0856
# Epoch 47: val_accuracy did not improve from 0.99097
# 526/526 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.9817 - loss: 0.0856 - val_accuracy: 0.9910 - val_loss: 0.0591 - learning_rate: 5.0000e-04
# Epoch 48/100
# 522/526 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9806 - loss: 0.0898
# Epoch 48: val_accuracy did not improve from 0.99097
# 526/526 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.9806 - loss: 0.0898 - val_accuracy: 0.9910 - val_loss: 0.0590 - learning_rate: 5.0000e-04
# Epoch 49/100
# 526/526 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9818 - loss: 0.0884
# Epoch 49: val_accuracy did not improve from 0.99097
# 526/526 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.9818 - loss: 0.0884 - val_accuracy: 0.9829 - val_loss: 0.0901 - learning_rate: 5.0000e-04
# Epoch 50/100
# 520/526 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9818 - loss: 0.0867
# Epoch 50: val_accuracy did not improve from 0.99097
# 526/526 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.9818 - loss: 0.0867 - val_accuracy: 0.9897 - val_loss: 0.0603 - learning_rate: 5.0000e-04
# Epoch 51/100
# 524/526 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9821 - loss: 0.0798
# Epoch 51: val_accuracy did not improve from 0.99097
# 526/526 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.9821 - loss: 0.0798 - val_accuracy: 0.9905 - val_loss: 0.0603 - learning_rate: 5.0000e-04
# Epoch 52/100
# 526/526 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9832 - loss: 0.0848
# Epoch 52: val_accuracy did not improve from 0.99097
# 526/526 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.9832 - loss: 0.0848 - val_accuracy: 0.9910 - val_loss: 0.0592 - learning_rate: 5.0000e-04
# Epoch 53/100
# 525/526 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9819 - loss: 0.0821
# Epoch 53: val_accuracy did not improve from 0.99097
# 526/526 ━━━━━━━━━━━━━━━━━━━━ 11s 11ms/step - accuracy: 0.9819 - loss: 0.0821 - val_accuracy: 0.9906 - val_loss: 0.0568 - learning_rate: 5.0000e-04
# Epoch 54/100
# 524/526 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9837 - loss: 0.0803
# Epoch 54: val_accuracy improved from 0.99097 to 0.99204, saving model to /content/drive/MyDrive/Colab_HAR_Project/results/TCN_Results_Merged_Sources_Colab/tcn_ABCDE_har_model.keras
# 526/526 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.9837 - loss: 0.0803 - val_accuracy: 0.9920 - val_loss: 0.0545 - learning_rate: 5.0000e-04
# Epoch 55/100
# 526/526 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9844 - loss: 0.0758
# Epoch 55: val_accuracy did not improve from 0.99204
# 526/526 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.9844 - loss: 0.0758 - val_accuracy: 0.9906 - val_loss: 0.0615 - learning_rate: 5.0000e-04
# Epoch 56/100
# 521/526 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9840 - loss: 0.0776
# Epoch 56: val_accuracy improved from 0.99204 to 0.99275, saving model to /content/drive/MyDrive/Colab_HAR_Project/results/TCN_Results_Merged_Sources_Colab/tcn_ABCDE_har_model.keras
# 526/526 ━━━━━━━━━━━━━━━━━━━━ 10s 10ms/step - accuracy: 0.9840 - loss: 0.0776 - val_accuracy: 0.9927 - val_loss: 0.0536 - learning_rate: 5.0000e-04
# Epoch 57/100
# 524/526 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9840 - loss: 0.0761
# Epoch 57: val_accuracy did not improve from 0.99275
# 526/526 ━━━━━━━━━━━━━━━━━━━━ 10s 10ms/step - accuracy: 0.9840 - loss: 0.0762 - val_accuracy: 0.9923 - val_loss: 0.0528 - learning_rate: 5.0000e-04
# Epoch 58/100
# 526/526 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9839 - loss: 0.0771
# Epoch 58: val_accuracy did not improve from 0.99275
# 526/526 ━━━━━━━━━━━━━━━━━━━━ 10s 10ms/step - accuracy: 0.9839 - loss: 0.0771 - val_accuracy: 0.9918 - val_loss: 0.0563 - learning_rate: 5.0000e-04
# Epoch 59/100
# 522/526 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9822 - loss: 0.0782
# Epoch 59: val_accuracy did not improve from 0.99275
# 526/526 ━━━━━━━━━━━━━━━━━━━━ 11s 11ms/step - accuracy: 0.9822 - loss: 0.0782 - val_accuracy: 0.9914 - val_loss: 0.0571 - learning_rate: 5.0000e-04
# Epoch 60/100
# 523/526 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9826 - loss: 0.0815
# Epoch 60: val_accuracy did not improve from 0.99275
# 526/526 ━━━━━━━━━━━━━━━━━━━━ 10s 11ms/step - accuracy: 0.9826 - loss: 0.0815 - val_accuracy: 0.9918 - val_loss: 0.0562 - learning_rate: 5.0000e-04
# Epoch 61/100
# 521/526 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9816 - loss: 0.0822
# Epoch 61: val_accuracy improved from 0.99275 to 0.99322, saving model to /content/drive/MyDrive/Colab_HAR_Project/results/TCN_Results_Merged_Sources_Colab/tcn_ABCDE_har_model.keras
# 526/526 ━━━━━━━━━━━━━━━━━━━━ 10s 11ms/step - accuracy: 0.9816 - loss: 0.0822 - val_accuracy: 0.9932 - val_loss: 0.0552 - learning_rate: 5.0000e-04
# Epoch 62/100
# 522/526 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9845 - loss: 0.0749
# Epoch 62: val_accuracy did not improve from 0.99322
#
# Epoch 62: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 526/526 ━━━━━━━━━━━━━━━━━━━━ 10s 9ms/step - accuracy: 0.9845 - loss: 0.0749 - val_accuracy: 0.9926 - val_loss: 0.0534 - learning_rate: 5.0000e-04
# Epoch 63/100
# 526/526 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9865 - loss: 0.0731
# Epoch 63: val_accuracy improved from 0.99322 to 0.99358, saving model to /content/drive/MyDrive/Colab_HAR_Project/results/TCN_Results_Merged_Sources_Colab/tcn_ABCDE_har_model.keras
# 526/526 ━━━━━━━━━━━━━━━━━━━━ 6s 11ms/step - accuracy: 0.9865 - loss: 0.0731 - val_accuracy: 0.9936 - val_loss: 0.0494 - learning_rate: 2.5000e-04
# Epoch 64/100
# 522/526 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9877 - loss: 0.0651
# Epoch 64: val_accuracy did not improve from 0.99358
# 526/526 ━━━━━━━━━━━━━━━━━━━━ 9s 9ms/step - accuracy: 0.9876 - loss: 0.0651 - val_accuracy: 0.9931 - val_loss: 0.0503 - learning_rate: 2.5000e-04
# Epoch 65/100
# 521/526 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9874 - loss: 0.0673
# Epoch 65: val_accuracy improved from 0.99358 to 0.99429, saving model to /content/drive/MyDrive/Colab_HAR_Project/results/TCN_Results_Merged_Sources_Colab/tcn_ABCDE_har_model.keras
# 526/526 ━━━━━━━━━━━━━━━━━━━━ 6s 11ms/step - accuracy: 0.9874 - loss: 0.0673 - val_accuracy: 0.9943 - val_loss: 0.0470 - learning_rate: 2.5000e-04
# Epoch 66/100
# 526/526 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9880 - loss: 0.0630
# Epoch 66: val_accuracy did not improve from 0.99429
# 526/526 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.9880 - loss: 0.0630 - val_accuracy: 0.9933 - val_loss: 0.0485 - learning_rate: 2.5000e-04
# Epoch 67/100
# 524/526 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9885 - loss: 0.0620
# Epoch 67: val_accuracy did not improve from 0.99429
# 526/526 ━━━━━━━━━━━━━━━━━━━━ 10s 9ms/step - accuracy: 0.9885 - loss: 0.0620 - val_accuracy: 0.9938 - val_loss: 0.0475 - learning_rate: 2.5000e-04
# Epoch 68/100
# 526/526 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9862 - loss: 0.0664
# Epoch 68: val_accuracy did not improve from 0.99429
# 526/526 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.9862 - loss: 0.0664 - val_accuracy: 0.9935 - val_loss: 0.0485 - learning_rate: 2.5000e-04
# Epoch 69/100
# 526/526 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9876 - loss: 0.0650
# Epoch 69: val_accuracy did not improve from 0.99429
# 526/526 ━━━━━━━━━━━━━━━━━━━━ 6s 10ms/step - accuracy: 0.9876 - loss: 0.0650 - val_accuracy: 0.9935 - val_loss: 0.0452 - learning_rate: 2.5000e-04
# Epoch 70/100
# 523/526 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9880 - loss: 0.0627
# Epoch 70: val_accuracy improved from 0.99429 to 0.99501, saving model to /content/drive/MyDrive/Colab_HAR_Project/results/TCN_Results_Merged_Sources_Colab/tcn_ABCDE_har_model.keras
# 526/526 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.9879 - loss: 0.0627 - val_accuracy: 0.9950 - val_loss: 0.0445 - learning_rate: 2.5000e-04
# Epoch 71/100
# 523/526 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9894 - loss: 0.0592
# Epoch 71: val_accuracy did not improve from 0.99501
# 526/526 ━━━━━━━━━━━━━━━━━━━━ 10s 10ms/step - accuracy: 0.9894 - loss: 0.0592 - val_accuracy: 0.9942 - val_loss: 0.0433 - learning_rate: 2.5000e-04
# Epoch 72/100
# 520/526 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9885 - loss: 0.0597
# Epoch 72: val_accuracy did not improve from 0.99501
# 526/526 ━━━━━━━━━━━━━━━━━━━━ 10s 10ms/step - accuracy: 0.9885 - loss: 0.0597 - val_accuracy: 0.9942 - val_loss: 0.0432 - learning_rate: 2.5000e-04
# Epoch 73/100
# 526/526 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9882 - loss: 0.0618
# Epoch 73: val_accuracy did not improve from 0.99501
# 526/526 ━━━━━━━━━━━━━━━━━━━━ 11s 11ms/step - accuracy: 0.9882 - loss: 0.0618 - val_accuracy: 0.9936 - val_loss: 0.0430 - learning_rate: 2.5000e-04
# Epoch 74/100
# 522/526 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9890 - loss: 0.0562
# Epoch 74: val_accuracy improved from 0.99501 to 0.99608, saving model to /content/drive/MyDrive/Colab_HAR_Project/results/TCN_Results_Merged_Sources_Colab/tcn_ABCDE_har_model.keras
# 526/526 ━━━━━━━━━━━━━━━━━━━━ 10s 10ms/step - accuracy: 0.9890 - loss: 0.0562 - val_accuracy: 0.9961 - val_loss: 0.0405 - learning_rate: 2.5000e-04
# Epoch 75/100
# 524/526 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9888 - loss: 0.0587
# Epoch 75: val_accuracy did not improve from 0.99608
# 526/526 ━━━━━━━━━━━━━━━━━━━━ 10s 10ms/step - accuracy: 0.9887 - loss: 0.0587 - val_accuracy: 0.9949 - val_loss: 0.0411 - learning_rate: 2.5000e-04
# Epoch 76/100
# 526/526 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9883 - loss: 0.0594
# Epoch 76: val_accuracy did not improve from 0.99608
# 526/526 ━━━━━━━━━━━━━━━━━━━━ 6s 11ms/step - accuracy: 0.9883 - loss: 0.0594 - val_accuracy: 0.9947 - val_loss: 0.0424 - learning_rate: 2.5000e-04
# Epoch 77/100
# 523/526 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9897 - loss: 0.0563
# Epoch 77: val_accuracy did not improve from 0.99608
# 526/526 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.9897 - loss: 0.0563 - val_accuracy: 0.9938 - val_loss: 0.0430 - learning_rate: 2.5000e-04
# Epoch 78/100
# 522/526 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9879 - loss: 0.0588
# Epoch 78: val_accuracy did not improve from 0.99608
# 526/526 ━━━━━━━━━━━━━━━━━━━━ 11s 11ms/step - accuracy: 0.9879 - loss: 0.0587 - val_accuracy: 0.9948 - val_loss: 0.0422 - learning_rate: 2.5000e-04
# Epoch 79/100
# 526/526 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9896 - loss: 0.0551
# Epoch 79: val_accuracy did not improve from 0.99608
#
# Epoch 79: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 526/526 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.9896 - loss: 0.0551 - val_accuracy: 0.9949 - val_loss: 0.0414 - learning_rate: 2.5000e-04
# Epoch 80/100
# 526/526 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9897 - loss: 0.0546
# Epoch 80: val_accuracy did not improve from 0.99608
# 526/526 ━━━━━━━━━━━━━━━━━━━━ 6s 11ms/step - accuracy: 0.9897 - loss: 0.0546 - val_accuracy: 0.9954 - val_loss: 0.0398 - learning_rate: 1.2500e-04
# Epoch 81/100
# 524/526 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9891 - loss: 0.0542
# Epoch 81: val_accuracy did not improve from 0.99608
# 526/526 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.9891 - loss: 0.0542 - val_accuracy: 0.9957 - val_loss: 0.0388 - learning_rate: 1.2500e-04
# Epoch 82/100
# 526/526 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9917 - loss: 0.0479
# Epoch 82: val_accuracy did not improve from 0.99608
# 526/526 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.9917 - loss: 0.0479 - val_accuracy: 0.9947 - val_loss: 0.0401 - learning_rate: 1.2500e-04
# Epoch 83/100
# 526/526 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9902 - loss: 0.0498
# Epoch 83: val_accuracy did not improve from 0.99608
# 526/526 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.9902 - loss: 0.0498 - val_accuracy: 0.9956 - val_loss: 0.0378 - learning_rate: 1.2500e-04
# Epoch 84/100
# 525/526 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9913 - loss: 0.0485
# Epoch 84: val_accuracy did not improve from 0.99608
# 526/526 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.9913 - loss: 0.0485 - val_accuracy: 0.9957 - val_loss: 0.0377 - learning_rate: 1.2500e-04
# Epoch 85/100
# 521/526 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9915 - loss: 0.0481
# Epoch 85: val_accuracy did not improve from 0.99608
# 526/526 ━━━━━━━━━━━━━━━━━━━━ 10s 9ms/step - accuracy: 0.9915 - loss: 0.0481 - val_accuracy: 0.9960 - val_loss: 0.0363 - learning_rate: 1.2500e-04
# Epoch 86/100
# 525/526 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9900 - loss: 0.0498
# Epoch 86: val_accuracy did not improve from 0.99608
# 526/526 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.9900 - loss: 0.0498 - val_accuracy: 0.9957 - val_loss: 0.0370 - learning_rate: 1.2500e-04
# Epoch 87/100
# 522/526 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9918 - loss: 0.0480
# Epoch 87: val_accuracy did not improve from 0.99608
# 526/526 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.9918 - loss: 0.0480 - val_accuracy: 0.9958 - val_loss: 0.0365 - learning_rate: 1.2500e-04
# Epoch 88/100
# 525/526 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9916 - loss: 0.0480
# Epoch 88: val_accuracy did not improve from 0.99608
# 526/526 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.9916 - loss: 0.0480 - val_accuracy: 0.9956 - val_loss: 0.0370 - learning_rate: 1.2500e-04
# Epoch 89/100
# 524/526 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9915 - loss: 0.0461
# Epoch 89: val_accuracy did not improve from 0.99608
# 526/526 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.9915 - loss: 0.0461 - val_accuracy: 0.9961 - val_loss: 0.0350 - learning_rate: 1.2500e-04
# Epoch 90/100
# 522/526 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9908 - loss: 0.0479
# Epoch 90: val_accuracy did not improve from 0.99608
# 526/526 ━━━━━━━━━━━━━━━━━━━━ 10s 10ms/step - accuracy: 0.9908 - loss: 0.0479 - val_accuracy: 0.9956 - val_loss: 0.0358 - learning_rate: 1.2500e-04
# Epoch 91/100
# 520/526 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9907 - loss: 0.0510
# Epoch 91: val_accuracy improved from 0.99608 to 0.99643, saving model to /content/drive/MyDrive/Colab_HAR_Project/results/TCN_Results_Merged_Sources_Colab/tcn_ABCDE_har_model.keras
# 526/526 ━━━━━━━━━━━━━━━━━━━━ 6s 11ms/step - accuracy: 0.9907 - loss: 0.0510 - val_accuracy: 0.9964 - val_loss: 0.0336 - learning_rate: 1.2500e-04
# Epoch 92/100
# 520/526 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9911 - loss: 0.0495
# Epoch 92: val_accuracy did not improve from 0.99643
# 526/526 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.9911 - loss: 0.0494 - val_accuracy: 0.9963 - val_loss: 0.0343 - learning_rate: 1.2500e-04
# Epoch 93/100
# 521/526 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9912 - loss: 0.0482
# Epoch 93: val_accuracy did not improve from 0.99643
# 526/526 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.9912 - loss: 0.0482 - val_accuracy: 0.9958 - val_loss: 0.0348 - learning_rate: 1.2500e-04
# Epoch 94/100
# 521/526 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9922 - loss: 0.0459
# Epoch 94: val_accuracy did not improve from 0.99643
# 526/526 ━━━━━━━━━━━━━━━━━━━━ 10s 9ms/step - accuracy: 0.9922 - loss: 0.0459 - val_accuracy: 0.9963 - val_loss: 0.0352 - learning_rate: 1.2500e-04
# Epoch 95/100
# 524/526 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9913 - loss: 0.0451
# Epoch 95: val_accuracy did not improve from 0.99643
# 526/526 ━━━━━━━━━━━━━━━━━━━━ 6s 11ms/step - accuracy: 0.9913 - loss: 0.0451 - val_accuracy: 0.9964 - val_loss: 0.0336 - learning_rate: 1.2500e-04
# Epoch 96/100
# 523/526 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9922 - loss: 0.0440
# Epoch 96: val_accuracy improved from 0.99643 to 0.99691, saving model to /content/drive/MyDrive/Colab_HAR_Project/results/TCN_Results_Merged_Sources_Colab/tcn_ABCDE_har_model.keras
# 526/526 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.9922 - loss: 0.0440 - val_accuracy: 0.9969 - val_loss: 0.0332 - learning_rate: 1.2500e-04
# Epoch 97/100
# 525/526 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9911 - loss: 0.0476
# Epoch 97: val_accuracy did not improve from 0.99691
# 526/526 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.9911 - loss: 0.0476 - val_accuracy: 0.9957 - val_loss: 0.0337 - learning_rate: 1.2500e-04
# Epoch 98/100
# 522/526 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9923 - loss: 0.0430
# Epoch 98: val_accuracy did not improve from 0.99691
# 526/526 ━━━━━━━━━━━━━━━━━━━━ 10s 9ms/step - accuracy: 0.9923 - loss: 0.0430 - val_accuracy: 0.9949 - val_loss: 0.0354 - learning_rate: 1.2500e-04
# Epoch 99/100
# 521/526 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9921 - loss: 0.0459
# Epoch 99: val_accuracy did not improve from 0.99691
# 526/526 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.9921 - loss: 0.0458 - val_accuracy: 0.9963 - val_loss: 0.0337 - learning_rate: 1.2500e-04
# Epoch 100/100
# 526/526 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9927 - loss: 0.0447
# Epoch 100: val_accuracy did not improve from 0.99691
# 526/526 ━━━━━━━━━━━━━━━━━━━━ 10s 10ms/step - accuracy: 0.9927 - loss: 0.0447 - val_accuracy: 0.9958 - val_loss: 0.0343 - learning_rate: 1.2500e-04
# Restoring model weights from the end of the best epoch: 96.
# Training finished.
# Training history plot saved to /content/drive/MyDrive/Colab_HAR_Project/results/TCN_Results_Merged_Sources_Colab/tcn_ABCDE_training_history.png
#
# Loading best model weights saved during training...
# Best model loaded successfully.
#
# [8/8] Evaluating model and saving results...
#
# Test Loss: 0.0339
# Test Accuracy: 0.9964
# 439/439 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step
# Classification report saved to /content/drive/MyDrive/Colab_HAR_Project/results/TCN_Results_Merged_Sources_Colab/tcn_ABCDE_classification_report.txt
#
#               precision    recall  f1-score   support
#
#            A     1.0000    0.9932    0.9966      4099
#            B     1.0000    1.0000    1.0000      2892
#            C     0.9883    1.0000    0.9941      1010
#            D     0.9947    0.9953    0.9950      3010
#            E     0.9927    0.9973    0.9950      3010
#
#     accuracy                         0.9964     14021
#    macro avg     0.9951    0.9972    0.9961     14021
# weighted avg     0.9965    0.9964    0.9964     14021
#
# Confusion matrix saved to /content/drive/MyDrive/Colab_HAR_Project/results/TCN_Results_Merged_Sources_Colab/tcn_ABCDE_confusion_matrix.png
# Test set predictions saved to /content/drive/MyDrive/Colab_HAR_Project/results/TCN_Results_Merged_Sources_Colab/tcn_ABCDE_test_predictions.csv
#
# --- Script finished in 755.41 seconds ---
